# %%
# %load_ext autoreload
# %autoreload 2

# %%
import tensorflow as tf
from tensorflow.keras import mixed_precision

import numpy as np
import glob
from tqdm.notebook import tqdm as tqdm
import os

from keras_helper import *
from skimage.transform import resize

import matplotlib.pyplot as plt
import matplotlib

import data_utils as dut
import complex_models as cmplxmod
from plot_utils import plot3

# Config the matplotlib backend as plotting inline in IPython
# %matplotlib inline

# %%
policy = mixed_precision.experimental.Policy('mixed_float16')
mixed_precision.experimental.set_policy(policy)

# %%
cmplxmod.DEFAULT_ACTIVATION = 'cleakyrelu'

# %%
if tf.config.list_physical_devices('GPU'):
  strategy = tf.distribute.MirroredStrategy()
else:  # Use the Default Strategy
  strategy = tf.distribute.get_strategy()
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1')

# %%
#print(os.environ["CUDA_VISIBLE_DEVICES"])
gpus = tf.config.experimental.list_physical_devices('GPU')
print(gpus)
if len(gpus):
  try:
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
      print("Restricting Memory")
  except RuntimeError as e:
    print(e)
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')]
# Physical devices cannot be modified after being initialized

# %%
# !nvidia-smi
# Out:
# Wed Aug 25 09:36:08 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.59       Driver Version: 440.59       CUDA Version: 10.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Quadro P4000        Off  | 00000000:03:00.0 Off |                  N/A |
# | 46%   31C    P0    28W / 105W |   7743MiB /  8119MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   1  Quadro P4000        Off  | 00000000:04:00.0  On |                  N/A |
# | 46%   35C    P0    28W / 105W |    637MiB /  8112MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |    0      4423      C   .../skandel/miniconda3/envs/tf2/bin/python  7731MiB |
# |    1      4423      C   .../skandel/miniconda3/envs/tf2/bin/python    79MiB |
# |    1     14629      G   /usr/libexec/Xorg                            109MiB |
# |    1     23153      G   /usr/libexec/Xorg                            191MiB |
# |    1     23241      G   /usr/bin/gnome-shell                         199MiB |
# |    1     24717      G   /usr/bin/gnome-shell                          43MiB |
# +-----------------------------------------------------------------------------+
# WARNING: infoROM is corrupted at gpu 0000:04:00.0

# %% [markdown]
# ### Some training parameters

# %%
path = './'

# %%
h,w=64,64
nepochs=60
wt_path = 'weights_cmplx/basic'
batch_size = 32

if (not os.path.isdir(path+wt_path)):
    os.mkdir(wt_path)

# %% [markdown]
# ### Read experimental diffraction data and reconstructed images

# %%
data_path = '../data/'
data_diffr_red, real_space = dut.read_experimental_data(data_path)

# %%
amplitudes = np.abs(real_space)
phases = np.angle(real_space)
amplitudes.shape
# Out:
# (161, 161, 64, 64)

# %%
fig,ax = plt.subplots(1,2,figsize=(20,10))
ax[0].imshow(amplitudes[:,:,32,32])
ax[1].imshow(phases[:,:,32,32])
# Out:
# findfont: Font family ['Times New Roman'] not found. Falling back to DejaVu Sans.

# %%
nlines = 100 #How many lines of data to use for training?
nltest = 60 #How many lines for the test set?

X_train, Y_train, X_test, Y_test = dut.get_train_test_data(x_data=data_diffr_red,
                                                           y_data=real_space,
                                                           n_train_lines=nlines,
                                                           n_test_lines=nltest,
                                                           img_h=h,
                                                           img_w=w)
# Out:
# Indexing the test set from 101
# Train shape (16100, 64, 64, 1) test shape (3600, 64, 64, 1)
# Shuffling the data using random state 0

# %%
# number of validation terms
val_size = np.floor(0.05 * X_train.shape[0]).astype('int')
train_size = X_train.shape[0] - val_size

# %%
x_dataset = tf.data.Dataset.from_tensor_slices(X_train)
y_dataset = tf.data.Dataset.from_tensor_slices(Y_train)

ds = tf.data.Dataset.zip((x_dataset, y_dataset))
ds = ds.shuffle(X_train.shape[0], seed=123)


ds_validation = ds.take(val_size)
ds_train = ds.skip(val_size)

ds_train = ds_train.shuffle(train_size, reshuffle_each_iteration=True)
ds_train = ds_train.batch(batch_size * len(gpus) * 2, drop_remainder=True)
ds_train = ds_train.prefetch(10)

ds_validation = ds_validation.batch(batch_size * len(gpus) * 2)
ds_validation = ds_validation.prefetch(4)

ds_test = tf.data.Dataset.from_tensor_slices(X_test)
ds_test = ds_test.batch(batch_size * len(gpus) * 2)

# %% [markdown]
# ## Define the network structure

# %%
tf.keras.backend.clear_session()
np.random.seed(123)

files=glob.glob('%s/*' % wt_path)
for file in files:
    os.remove(file)

#plot_model(autoencoder, to_file='paper_data/str_model.png')

# %%
with strategy.scope():
    model = cmplxmod.create_basic_model(h, w)

# %%
out = model(X_train[0][None, :])

# %%
plt.pcolormesh(np.angle(np.squeeze(np.angle(out))))
plt.colorbar()

# %%
plt.pcolormesh(np.abs(np.squeeze(out)))
plt.colorbar()

# %%
cmplxmod.full_summary(model)
# Out:
# summary for model
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 64, 64, 1)]       0
# _________________________________________________________________
# complex_conv2d (ComplexConv2 (None, 64, 64, 32)        640
# _________________________________________________________________
# complex_conv2d_1 (ComplexCon (None, 32, 32, 32)        18496
# _________________________________________________________________
# complex_conv2d_2 (ComplexCon (None, 32, 32, 64)        36992
# _________________________________________________________________
# complex_conv2d_3 (ComplexCon (None, 16, 16, 64)        73856
# _________________________________________________________________
# complex_conv2d_4 (ComplexCon (None, 16, 16, 128)       147712
# _________________________________________________________________
# complex_conv2d_5 (ComplexCon (None, 8, 8, 128)         295168
# _________________________________________________________________
# complex_conv2d_6 (ComplexCon (None, 8, 8, 128)         295168
# _________________________________________________________________
# complex_conv2d_transpose (Co (None, 16, 16, 128)       295168
# _________________________________________________________________
# complex_conv2d_7 (ComplexCon (None, 16, 16, 64)        147584
# _________________________________________________________________
# complex_conv2d_transpose_1 ( (None, 32, 32, 64)        73856
# _________________________________________________________________
# complex_conv2d_8 (ComplexCon (None, 32, 32, 32)        36928
# _________________________________________________________________
# complex_conv2d_transpose_2 ( (None, 64, 64, 32)        18496
# _________________________________________________________________
# complex_conv2d_9 (ComplexCon (None, 64, 64, 1)         578
# =================================================================
# Total params: 1,440,642
# Trainable params: 1,440,642
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='mean_squared_error', run_eagerly=False)

# %%
histories = []

# %%
for i in range(1):
    
    reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5,
                                  patience=2, min_lr=0.0001, verbose=1)


    checkpoints= tf.keras.callbacks.ModelCheckpoint(wt_path + '/weights' + '.{epoch:02d}.h5',
                                                    monitor='val_loss', verbose=1, save_best_only=True, 
                                                    save_weights_only=True, mode='auto', save_freq='epoch')




    history = model.fit(ds_train, validation_data=ds_validation, verbose=1,
                    epochs=50,  callbacks=[checkpoints, reduce_lr],
                    use_multiprocessing=True, workers=8)
    histories.append(history)
# Out:
# Epoch 1/50
# 119/119 [==============================] - ETA: 0s - loss: 1.2924e-04
# Epoch 00001: val_loss improved from inf to 0.00013, saving model to weights_cmplx/basic/weights.01.h5
# 119/119 [==============================] - 48s 400ms/step - loss: 1.2924e-04 - val_loss: 1.2709e-04 - lr: 1.0000e-04
# Epoch 2/50
# 119/119 [==============================] - ETA: 0s - loss: 1.2850e-04
# Epoch 00002: val_loss improved from 0.00013 to 0.00013, saving model to weights_cmplx/basic/weights.02.h5
# 119/119 [==============================] - 48s 404ms/step - loss: 1.2850e-04 - val_loss: 1.2548e-04 - lr: 1.0000e-04
# Epoch 3/50
# 119/119 [==============================] - ETA: 0s - loss: 1.
val_loss did not improve from 0.00011
# 119/119 [==============================] - 48s 405ms/step - loss: 1.1031e-04 - val_loss: 1.1013e-04 - lr: 1.0000e-04
# Epoch 38/50
# 119/119 [==============================] - ETA: 0s - loss: 1.1006e-04
# Epoch 00038: val_loss improved from 0.00011 to 0.00011, saving model to weights_cmplx/basic/weights.38.h5
# 119/119 [==============================] - 48s 403ms/step - loss: 1.1006e-04 - val_loss: 1.0632e-04 - lr: 1.0000e-04
# Epoch 39/50
# 119/119 [==============================] - ETA: 0s - loss: 1.0922e-04
# Epoch 00039: val_loss did not improve from 0.00011
# 119/119 [==============================] - 48s 404ms/step - loss: 1.0922e-04 - val_loss: 1.0896e-04 - lr: 1.0000e-04
# Epoch 40/50
# 119/119 [==============================] - ETA: 0s - loss: 1.0872e-04
# Epoch 00040: val_loss did not improve from 0.00011
# 119/119 [==============================] - 48s 406ms/step - loss: 1.0872e-04 - val_loss: 1.0885e-04 - lr: 1.0000e-04
# Epoch 41/50
# 119/119 [==============================] - ETA: 0s - loss: 1.0892e-04
# Epoch 00041: val_loss did not improve from 0.00011
# 119/119 [==============================] - 48s 402ms/step - loss: 1.0892e-04 - val_loss: 1.0830e-04 - lr: 1.0000e-04
# Epoch 42/50
# 119/119 [==============================] - ETA: 0s - loss: 1.0892e-04
# Epoch 00042: val_loss did not improve from 0.00011
# 119/119 [==============================] - 47s 399ms/step - loss: 1.0892e-04 - val_loss: 1.0655e-04 - lr: 1.0000e-04
# Epoch 43/50
# 119/119 [==============================] - ETA: 0s - loss: 1.0831e-04
# Epoch 00043: val_loss improved from 0.00011 to 0.00011, saving model to weights_cmplx/basic/weights.43.h5
# 119/119 [==============================] - 48s 401ms/step - loss: 1.0831e-04 - val_loss: 1.0621e-04 - lr: 1.0000e-04
# Epoch 44/50
# 119/119 [==============================] - ETA: 0s - loss: 1.0811e-04
# Epoch 00044: val_loss improved from 0.00011 to 0.00010, saving model to weights_cmplx/basic/weights.44.h5
# 119/119 [==============================] - 48s 407ms/step - loss: 1.0811e-04 - val_loss: 1.0377e-04 - lr: 1.0000e-04
# Epoch 45/50
# 119/119 [==============================] - ETA: 0s - loss: 1.0738e-04
# Epoch 00045: val_loss did not improve from 0.00010
# 119/119 [==============================] - 48s 403ms/step - loss: 1.0738e-04 - val_loss: 1.0469e-04 - lr: 1.0000e-04
# Epoch 46/50
# 119/119 [==============================] - ETA: 0s - loss: 1.0695e-04
# Epoch 00046: val_loss did not improve from 0.00010
# 119/119 [==============================] - 48s 405ms/step - loss: 1.0695e-04 - val_loss: 1.0671e-04 - lr: 1.0000e-04
# Epoch 47/50
# 119/119 [==============================] - ETA: 0s - loss: 1.0653e-04
# Epoch 00047: val_loss did not improve from 0.00010
# 119/119 [==============================] - 48s 402ms/step - loss: 1.0653e-04 - val_loss: 1.0531e-04 - lr: 1.0000e-04
# Epoch 48/50
# 119/119 [==============================] - ETA: 0s - loss: 1.0626e-04
# Epoch 00048: val_loss did not improve from 0.00010
# 119/119 [==============================] - 48s 406ms/step - loss: 1.0626e-04 - val_loss: 1.0407e-04 - lr: 1.0000e-04
# Epoch 49/50
# 119/119 [==============================] - ETA: 0s - loss: 1.0654e-04
# Epoch 00049: val_loss improved from 0.00010 to 0.00010, saving model to weights_cmplx/basic/weights.49.h5
# 119/119 [==============================] - 48s 403ms/step - loss: 1.0654e-04 - val_loss: 1.0302e-04 - lr: 1.0000e-04
# Epoch 50/50
# 119/119 [==============================] - ETA: 0s - loss: 1.0611e-04
# Epoch 00050: val_loss did not improve from 0.00010
# 119/119 [==============================] - 48s 402ms/step - loss: 1.0611e-04 - val_loss: 1.0409e-04 - lr: 1.0000e-04

# %%
histories
# Out:
# [<tensorflow.python.keras.callbacks.History at 0x7ff674152520>,
#  <tensorflow.python.keras.callbacks.History at 0x7ff6654d0700>,
#  <tensorflow.python.keras.callbacks.History at 0x7ff568073460>,
#  <tensorflow.python.keras.callbacks.History at 0x7ff6579b9b80>]

# %% [markdown]
# ## Plot metrics of the training

# %%
for i in range(len(histories)):
    if i == 0:
        epochs = np.array(histories[0].epoch)
        training_losses = np.array(histories[0].history['loss'])
        val_losses =np.array(histories[0].history['val_loss'])
    else:
        epochs = np.concatenate([epochs, epochs[-1] + np.array(histories[i].epoch) + 1], axis=0)
        training_losses = np.concatenate([training_losses,  histories[i].history['loss']], axis=0)
        val_losses =  np.concatenate([val_losses, histories[i].history['val_loss']], axis=0)

# %%
f, axarr = plt.subplots(1, sharex=True, figsize=(8, 4))

axarr.set(ylabel='Loss')
axarr.plot(epochs[1:], training_losses[1:], color='red', marker='d', markevery=0.2, label='Training')
axarr.plot(epochs[1:], val_losses[1:], color='blue', marker='o', markevery=0.2, label='Validation')
axarr.grid()
axarr.legend(loc='center right', bbox_to_anchor=(1.5, 0.5))
axarr.set_yscale('log')
plt.xlabel('Epochs')

#axarr[1].set(ylabel='Loss')
#axarr[1].plot(epochs,hist_large.history['conv2d_12_loss'], 'C0o', label='Structure Training')
#axarr[1].plot(epochs,hist_large.history['val_conv2d_12_loss'], 'C0-', label='Structure Validation')
#axarr[1].legend(loc='center right', bbox_to_anchor=(1.5, 0.5))

#plt.tight_layout()
#axarr[1].grid()


#axarr[2].set(ylabel='Loss')
#axarr[2].plot(epochs,hist_large.history['conv2d_19_loss'], 'C0o', label='Phase Training')
#axarr[2].plot(epochs,hist_large.history['val_conv2d_19_loss'], 'C0-', label='Phase Validation')
#axarr[2].legend(loc='center right', bbox_to_anchor=(1.5, 0.5))
#plt.tight_layout()
#axarr[2].grid()

#plt.show()

#print(np.min(hist_large.history['val_conv2d_12_loss']), np.min(hist_large.history['val_conv2d_19_loss']), np.min(hist_large.history['val_loss']))
# Out:
# Text(0.5, 0, 'Epochs')

# %% [markdown]
# ### Save the epoch with the lowest validation loss
# (PtychoNN will use these weights)

# %%
min_epoch = np.argmin(val_losses) + 1
print (min_epoch)
np.save(f'{path}/{wt_path}/min_epoch', min_epoch)
# Out:
# 114

# %%
# !ls weights_cmplx_ft/basic
# Out:
# min_epoch.npy  weights.16.h5  weights.32.h5  weights.48.h5  weights.67.h5
# weights.01.h5  weights.17.h5  weights.33.h5  weights.49.h5  weights.69.h5
# weights.02.h5  weights.18.h5  weights.34.h5  weights.50.h5  weights.70.h5
# weights.03.h5  weights.19.h5  weights.35.h5  weights.51.h5  weights.72.h5
# weights.04.h5  weights.20.h5  weights.36.h5  weights.52.h5  weights.73.h5
# weights.05.h5  weights.21.h5  weights.37.h5  weights.54.h5  weights.74.h5
# weights.06.h5  weights.22.h5  weights.38.h5  weights.55.h5  weights.75.h5
# weights.07.h5  weights.23.h5  weights.39.h5  weights.57.h5  weights.79.h5
# weights.08.h5  weights.24.h5  weights.40.h5  weights.58.h5  weights.80.h5
# weights.09.h5  weights.25.h5  weights.41.h5  weights.59.h5  weights.82.h5
# weights.10.h5  weights.26.h5  weights.42.h5  weights.60.h5  weights.85.h5
# weights.11.h5  weights.27.h5  weights.43.h5  weights.61.h5  weights.87.h5
# weights.12.h5  weights.28.h5  weights.44.h5  weights.63.h5  weights.88.h5
# weights.13.h5  weights.29.h5  weights.45.h5  weights.64.h5  weights.89.h5
# weights.14.h5  weights.30.h5  weights.46.h5  weights.65.h5  weights.90.h5
# weights.15.h5  weights.31.h5  weights.47.h5  weights.66.h5  weights.93.h5

# %% [markdown]
# ### Load the model from the epoch with lowest validation error

# %% [raw]
# min_epoch = np.load(f'{wt_path}/min_epoch.npy')
#
# model_loaded = cmplxmod.create_basic_model(h, w)
#
# #model_loaded.load_weights(f'{wt_path}/weights.{min_epoch:02}.h5')
#
# #model = load_model(f'{wt_path}/weights.{min_epoch:02}.hdf5')
# print ("Loaded model from epoch:%d" %min_epoch)
#
# preds=np.array(model_loaded.predict(X_test))
# print (preds_intens[0].shape)

# %% [markdown]
# ### Make prediction using the diffraction data alone

# %% [raw]
# preds = model.predict(X_test)

# %%
preds = model.predict(ds_test)

# %%
preds_intens = np.array([np.abs(preds), np.angle(preds)])

# %% [markdown]
# # Plot some instances of the test data, it's FT and the CNN prediction

# %%
preds_intens.shape
# Out:
# (2, 3600, 64, 64, 1)

# %%
Y_test.shape
# Out:
# (3600, 64, 64, 1)

# %%
h,w = 64, 64
ntest = preds_intens[0].shape[0]
plt.viridis()
n = 5
f,ax=plt.subplots(7,n,figsize=(20, 15))
plt.gcf().text(0.02, 0.85, "Input", fontsize=20)
plt.gcf().text(0.02, 0.72, "True I", fontsize=20)
plt.gcf().text(0.02, 0.6, "Predicted I", fontsize=20)
plt.gcf().text(0.02, 0.5, "Difference I", fontsize=20)
plt.gcf().text(0.02, 0.4, "True Phi", fontsize=20)
plt.gcf().text(0.02, 0.27, "Predicted Phi", fontsize=20)
plt.gcf().text(0.02, 0.17, "Difference Phi", fontsize=20)

for i in range(0,n):
    j=int(round(np.random.rand()*ntest))

        # display FT
    im=ax[0,i].imshow(np.log10(np.abs(X_test[j]).reshape(h, w)+1))
    plt.colorbar(im, ax=ax[0,i], format='%.2f')
    ax[0,i].get_xaxis().set_visible(False)
    ax[0,i].get_yaxis().set_visible(False)

    # display original intens
    im=ax[1,i].imshow(np.abs(Y_test[j]).reshape(h, w))
    plt.colorbar(im, ax=ax[1,i], format='%.2f')
    ax[1,i].get_xaxis().set_visible(False)
    ax[1,i].get_yaxis().set_visible(False)
    
    # display predicted intens
    im=ax[2,i].imshow(preds_intens[0][j].reshape(h, w))
    plt.colorbar(im, ax=ax[2,i], format='%.2f')
    ax[2,i].get_xaxis().set_visible(False)
    ax[2,i].get_yaxis().set_visible(False)
    
        # display original phase
    im=ax[4,i].imshow(np.angle(Y_test[j]).reshape(h, w))
    plt.colorbar(im, ax=ax[4,i], format='%.2f')
    ax[4,i].get_xaxis().set_visible(False)
    ax[4,i].get_yaxis().set_visible(False)
    
    # display predicted phase
    im=ax[5,i].imshow(preds_intens[1][j].reshape(h, w))
    plt.colorbar(im, ax=ax[5,i], format='%.2f')
    ax[5,i].get_xaxis().set_visible(False)
    ax[5,i].get_yaxis().set_visible(False)
    
    #Difference in amplitude
    im=ax[3,i].imshow(np.abs(Y_test[j]).reshape(h, w)-preds_intens[0][j].reshape(h, w))
    plt.colorbar(im, ax=ax[3,i], format='%.2f')
    ax[3,i].get_xaxis().set_visible(False)
    ax[3,i].get_yaxis().set_visible(False)
    
    # Difference in phase
    im=ax[6,i].imshow(np.angle(Y_test[j]).reshape(h, w)-preds_intens[1][j].reshape(h, w))
    plt.colorbar(im, ax=ax[6,i], format='%.2f')
    ax[6,i].get_xaxis().set_visible(False)
    ax[6,i].get_yaxis().set_visible(False)
    
plt.show()

# %%
point_size = 3
overlap = 4*point_size

# %%
tst_side = 60

composite = np.zeros((tst_side*point_size+overlap,tst_side*point_size+overlap),'complex64')
ctr = np.zeros_like(composite)
preds_reshaped = preds.reshape(tst_side,tst_side,64,64)[:,:,32-int(overlap/2):32+int(overlap/2),
                                                     32-int(overlap/2):32+int(overlap/2)]

for i in range(tst_side):
    for j in range(tst_side):
        composite[point_size*i:point_size*i+overlap, point_size*j:point_size*j+overlap] += preds_reshaped[i,j]
        ctr[point_size*i:point_size*i+overlap, point_size*j:point_size*j+overlap] +=1

# %%
composite_amp = np.zeros((tst_side*point_size+overlap,tst_side*point_size+overlap),float)
ctr = np.zeros_like(composite_amp)

data_reshaped = preds_intens[0].reshape(tst_side,tst_side,64,64)[:,:,32-int(overlap/2):32+int(overlap/2),
                                                     32-int(overlap/2):32+int(overlap/2)]

for i in range(tst_side):
    for j in range(tst_side):
        composite_amp[point_size*i:point_size*i+overlap, point_size*j:point_size*j+overlap] += data_reshaped[i,j]
        ctr[point_size*i:point_size*i+overlap, point_size*j:point_size*j+overlap] +=1

# %%
composite_phase = np.zeros((tst_side*point_size+overlap,tst_side*point_size+overlap),float)
ctr = np.zeros_like(composite_phase)
data_reshaped = preds_intens[1].reshape(tst_side,tst_side,64,64)[:,:,32-int(overlap/2):32+int(overlap/2),
                                                     32-int(overlap/2):32+int(overlap/2)]

for i in range(tst_side):
    for j in range(tst_side):
        composite_phase[point_size*i:point_size*i+overlap, point_size*j:point_size*j+overlap] += data_reshaped[i,j]
        ctr[point_size*i:point_size*i+overlap, point_size*j:point_size*j+overlap] +=1

# %%
stitched = (composite[int(overlap/2):-int(overlap/2), int(overlap/2):-int(overlap/2)] 
            / ctr[int(overlap/2)  :-int(overlap/2), int(overlap/2):-int(overlap/2)])

stitched_down = (resize(np.real(stitched), (60,60), preserve_range=True, anti_aliasing=True) + 
                 resize(np.imag(stitched), (60,60), preserve_range=True, anti_aliasing=True) * 1j)

# %%
stitched_phase = composite_phase[int(overlap/2):-int(overlap/2), int(overlap/2):-int(overlap/2)]/ctr[int(overlap/2)
                                                                    :-int(overlap/2), int(overlap/2):-int(overlap/2)]

stitched_amp = composite_amp[int(overlap/2):-int(overlap/2), int(overlap/2):-int(overlap/2)]/ctr[int(overlap/2)
                                                                    :-int(overlap/2), int(overlap/2):-int(overlap/2)]

stitched_amp_down = resize(stitched_amp, (60,60), preserve_range=True, anti_aliasing=True)
stitched_phase_down = resize(stitched_phase, (60,60), preserve_range=True, anti_aliasing=True)

# %%
true_amp = np.abs(Y_test).reshape(nltest, nltest, 64,64)
true_ph = np.angle(Y_test).reshape(nltest, nltest, 64,64)

# %%
plot3([true_amp[:,:,32,32],stitched_amp_down,stitched_amp_down-true_amp[:,:,32,32]],['ePIE', 'pred', 'diff'])

# %%
plot3([true_ph[:,:,32,32],stitched_phase_down,stitched_phase_down-true_ph[:,:,32,32]],
      ['ePIE', 'pred', 'diff'])

# %%
stitched.shape
# Out:
# (180, 180)

# %%
plot3([true_amp[:,:,32,32], np.abs(stitched_down), 
       np.abs(stitched_down) - true_amp[:,:,32,32]],['ePIE', 'pred', 'diff'])

# %%
plot3([true_ph[:,:,32,32], np.angle(stitched_down), 
       np.angle(stitched_down) - true_ph[:,:,32,32]],['ePIE', 'pred', 'diff'])

# %%
from sklearn.metrics import mean_squared_error as mse
from skimage.registration import phase_cross_correlation
print ("MSE in amplitude: ", mse(stitched_amp_down, true_amp[:,:,32,32]))
print ("MSE in phase: ", mse(stitched_phase_down, true_ph[:,:,32,32]))
# Out:
# MSE in amplitude:  3.881853563114285e-05
# MSE in phase:  0.08210099887339535

# %%
true_img = true_amp * np.exp(1j * true_ph)
stitched_img = stitched_amp_down * np.exp(1j * stitched_phase_down)

# %%
_roll, _err, _phase = phase_cross_correlation(true_img[:,:,32, 32], stitched_img)
phase_cross_correlation(true_img[:,:,32,32], stitched_img * np.exp(1j * _phase))
# Out:
# (array([0., 0.]), 0.21741451499272016, 6.282261769364398e-17)

# %%
_roll, _err, _phase = phase_cross_correlation(true_img[:,:,32, 32], stitched_down)
phase_cross_correlation(true_img[:,:,32,32], stitched_down * np.exp(1j * _phase))
# Out:
# (array([0., 0.]), 0.21552390369728797, 2.064550616081898e-18)
